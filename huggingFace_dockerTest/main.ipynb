# %%
from huggingface_hub import InferenceClient

client = InferenceClient(
    model="http://localhost:9000",  # URL to the TGI server
)

# Text generation
response = client.text_generation(
    "Tell me a story",
    max_new_tokens=100,
    temperature=0.7,
    top_p=0.95,
    details=True,
    stop_sequences=[],
)
print(response.generated_text)

# For chat format
response = client.chat_completion(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Tell me a story"},
    ],
    max_tokens=100,
    temperature=0.7,
    top_p=0.95,
)
print(response.choices[0].message.content)
# Out:
# Tell me a story.
#
# I was walking through the old town, the cobblestones crunching beneath my feet. It's been a while since I've had a good walk. The sun's been setting over the rooftops, casting a warm orange glow over the cobblestones. The streets are quiet, just the sound of the wind rustling through the trees. I've been walking for hours, trying to clear my head.
#
# As I turned a corner, I saw a woman standing on the
# Once upon a time, in a small village nestled between the mountains and the sea, there lived a kind-hearted monk named Brother Amber. Brother Amber was a humble monk, always seeking to spread the message of peace, love, and compassion. He lived a simple life, dedicating his days to meditation and prayer, and his nights to sharing stories from the scriptures.
#
# One day, while wandering through the forest, Brother Amber stumbled upon an old, mysterious-looking book.
